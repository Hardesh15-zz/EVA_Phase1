# %% [markdown]
# ## Importing Keras Libraries and Modules

# %%
from keras import backend as K
import numpy as np
import time
import cv2
import sys
# Importing matplot library
import matplotlib.pyplot as plt
% matplotlib inline
# Seed the generator
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D,Conv2D
from keras.layers import Activation, Flatten, Dense, Dropout,SpatialDropout2D, GlobalAveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils

# %% [markdown]
# ##Importing Cifar10 dataset

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %% [markdown]
# ## Ploting each class from cifar10 dataset

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %% [markdown]
# ##  Function for ploting model history

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %% [markdown]
# ##  Function for accuracy

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %% [markdown]
# ## Converting Class Labels

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %% [markdown]
# ##  Define the model

# %%
model = Sequential()

model.add(Conv2D(48, (3, 3), activation='relu', padding ='same', input_shape=(32, 32, 3))) #32
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Conv2D(48, (3, 3), activation='relu')) #30
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(MaxPooling2D(pool_size=(2, 2))) #15


model.add(Conv2D(96, (3, 3), activation='relu', padding ='same')) # 15
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Conv2D(192, (3, 3), activation='relu')) # 13
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Conv2D(192, (3, 3), activation='relu')) # 11
model.add(BatchNormalization())
model.add(Dropout(0.25))


#model.add(MaxPooling2D(pool_size=(2, 2))) #5


model.add(Conv2D(192, (3, 3), activation='relu', padding ='same')) #5
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Conv2D(192, (3, 3), activation='relu')) # 5
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Conv2D(192, (3, 3), activation='relu')) # 3
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(10, 1, name = 'last_layer'))#1
model.add(GlobalAveragePooling2D())

#model.add(Flatten())
model.add(Activation('softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of model
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_17 (Conv2D)           (None, 32, 32, 48)        1344
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 32, 32, 48)        192
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 30, 30, 48)        20784
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 30, 30, 48)        192
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 30, 30, 48)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 48)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 15, 15, 96)        41568
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 15, 15, 96)        384
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 15, 15, 96)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 13, 13, 192)       166080
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 13, 13, 192)       768
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 13, 13, 192)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 11, 11, 192)       331968
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 11, 11, 192)       768
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 11, 11, 192)       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 11, 11, 192)       331968
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 11, 11, 192)       768
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 11, 11, 192)       0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 9, 9, 192)         331968
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 9, 9, 192)         768
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 9, 9, 192)         0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 7, 7, 192)         331968
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 7, 7, 192)         768
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 7, 7, 192)         0
# _________________________________________________________________
# last_layer (Conv2D)          (None, 7, 7, 10)          1930
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 10)                0
# _________________________________________________________________
# activation_3 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,564,186
# Trainable params: 1,561,882
# Non-trainable params: 2,304
# _________________________________________________________________

# %% [markdown]
# ## Training Model
# ## Epochs 100

# %%
# Image Normalization
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
datagen = ImageDataGenerator(zoom_range=0.0,horizontal_flip=False)
# train the model
start = time.time()
def scheduler(epoch, lr):
  return round(0.003 * 1/(1 + 0.319 * epoch), 10)

# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 steps_per_epoch = train_features.shape[0]/128, epochs = 100, 
                                 validation_data = (test_features, test_labels),callbacks=[LearningRateScheduler(scheduler, verbose=1)])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))

# plot model history
plot_model_history(model_info)

# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# Epoch 1/100
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.003.
# 391/390 [==============================] - 120s 306ms/step - loss: 1.4314 - acc: 0.4842 - val_loss: 1.4340 - val_acc: 0.5084
# Epoch 2/100
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0022744503.
# 391/390 [==============================] - 104s 266ms/step - loss: 0.9684 - acc: 0.6541 - val_loss: 1.1647 - val_acc: 0.6017
# Epoch 3/100
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0018315018.
# 391/390 [==============================] - 104s 266ms/step - loss: 0.7729 - acc: 0.7293 - val_loss: 0.9135 - val_acc: 0.7023
# Epoch 4/100
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0015329586.
# 391/390 [==============================] - 104s 266ms/step - loss: 0.6510 - acc: 0.7730 - val_loss: 0.8299 - val_acc: 0.7188
# Epoch 5/100
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.0013181019.
# 391/390 [==============================] - 104s 266ms/step - loss: 0.5701 - acc: 0.8031 - val_loss: 0.6673 - val_acc: 0.7756
# Epoch 6/100
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.0011560694.
# 391/390 [==============================] - 104s 266ms/step - loss: 0.5051 - acc: 0.8235 - val_loss: 0.7132 - val_acc: 0.7670
# Epoch 7/100
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.0010295127.
# 391/390 [==============================] - 105s 267ms/step - loss: 0.4478 - acc: 0.8443 - val_loss: 0.5914 - val_acc: 0.7990
# Epoch 8/100
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0009279307.
# 391/390 [==============================] - 104s 266ms/step - loss: 0.4075 - acc: 0.8566 - val_loss: 0.5859 - val_acc: 0.8028
# Epoch 9/100
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0008445946.
# 391/390 [==============================] - 104s 266ms/step - loss: 0.3716 - acc: 0.8693 - val_loss: 0.5483 - val_acc: 0.8208
# Epoch 10/100
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0007749935.
# 391/390 [==============================] - 104s 266ms/step - loss: 0.3313 - acc: 0.8847 - val_loss: 0.4974 - val_acc: 0.8369
# Epoch 11/100
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0007159905.
# 391/390 [==============================] - 105s 268ms/step - loss: 0.2971 - acc: 0.8937 - val_loss: 0.5043 - val_acc: 0.8373
# Epoch 12/100
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.000665336.
# 391/390 [==============================] - 105s 268ms/step - loss: 0.2798 - acc: 0.9007 - val_loss: 0.5617 - val_acc: 0.8234
# Epoch 13/100
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0006213753.
# 391/390 [==============================] - 105s 268ms/step - loss: 0.2502 - acc: 0.9135 - val_loss: 0.5526 - val_acc: 0.8282
# Epoch 14/100
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0005828638.
# 391/390 [==============================] - 105s 268ms/step - loss: 0.2302 - acc: 0.9177 - val_loss: 0.4969 - val_acc: 0.8481
# Epoch 15/100
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0005488474.
# 391/390 [==============================] - 105s 268ms/step - loss: 0.2102 - acc: 0.9246 - val_loss: 0.5223 - val_acc: 0.8432
# Epoch 16/100
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.0005185825.
# 391/390 [==============================] - 97s 249ms/step - loss: 0.1971 - acc: 0.9295 - val_loss: 0.5227 - val_acc: 0.8465
# Epoch 17/100
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.000491481.
# 391/390 [==============================] - 55s 140ms/step - loss: 0.1819 - acc: 0.9351 - val_loss: 0.5288 - val_acc: 0.8487
# Epoch 18/100
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0004670715.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.1663 - acc: 0.9403 - val_loss: 0.5336 - val_acc: 0.8448
# Epoch 19/100
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0004449718.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.1533 - acc: 0.9456 - val_loss: 0.5361 - val_acc: 0.8475
# Epoch 20/100
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.000424869.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.1472 - acc: 0.9471 - val_loss: 0.5175 - val_acc: 0.8562
# Epoch 21/100
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0004065041.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.1344 - acc: 0.9525 - val_loss: 0.5311 - val_acc: 0.8543
# Epoch 22/100
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.000389661.
# 391/390 [==============================] - 54s 137ms/step - loss: 0.1290 - acc: 0.9536 - val_loss: 0.5777 - val_acc: 0.8462
# Epoch 23/100
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.0003741581.
# 391/390 [==============================] - 54s 137ms/step - loss: 0.1158 - acc: 0.9579 - val_loss: 0.5592 - val_acc: 0.8510
# Epoch 24/100
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.0003598417.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.1082 - acc: 0.9616 - val_loss: 0.5514 - val_acc: 0.8562
# Epoch 25/100
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.0003465804.
# 391/390 [==============================] - 54s 137ms/step - loss: 0.1059 - acc: 0.9626 - val_loss: 0.5626 - val_acc: 0.8543
# Epoch 26/100
#
# Epoch 00026: LearningRateScheduler setting learning rate to 0.0003342618.
# 391/390 [==============================] - 54s 137ms/step - loss: 0.0998 - acc: 0.9639 - val_loss: 0.5911 - val_acc: 0.8526
# Epoch 27/100
#
# Epoch 00027: LearningRateScheduler setting learning rate to 0.0003227889.
# 391/390 [==============================] - 54s 137ms/step - loss: 0.0953 - acc: 0.9655 - val_loss: 0.5228 - val_acc: 0.8648
# Epoch 28/100
#
# Epoch 00028: LearningRateScheduler setting learning rate to 0.0003120774.
# 391/390 [==============================] - 54s 137ms/step - loss: 0.0918 - acc: 0.9669 - val_loss: 0.5554 - val_acc: 0.8622
# Epoch 29/100
#
# Epoch 00029: LearningRateScheduler setting learning rate to 0.000302054.
# 391/390 [==============================] - 54s 137ms/step - loss: 0.0874 - acc: 0.9687 - val_loss: 0.5605 - val_acc: 0.8629
# Epoch 30/100
#
# Epoch 00030: LearningRateScheduler setting learning rate to 0.0002926544.
# 391/390 [==============================] - 54s 137ms/step - loss: 0.0821 - acc: 0.9702 - val_loss: 0.5860 - val_acc: 0.8606
# Epoch 31/100
#
# Epoch 00031: LearningRateScheduler setting learning rate to 0.0002838221.
# 391/390 [==============================] - 54s 137ms/step - loss: 0.0784 - acc: 0.9720 - val_loss: 0.6092 - val_acc: 0.8565
# Epoch 32/100
#
# Epoch 00032: LearningRateScheduler setting learning rate to 0.0002755074.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0753 - acc: 0.9732 - val_loss: 0.6110 - val_acc: 0.8561
# Epoch 33/100
#
# Epoch 00033: LearningRateScheduler setting learning rate to 0.000267666.
# 391/390 [==============================] - 54s 137ms/step - loss: 0.0755 - acc: 0.9730 - val_loss: 0.5949 - val_acc: 0.8592
# Epoch 34/100
#
# Epoch 00034: LearningRateScheduler setting learning rate to 0.0002602585.
# 391/390 [==============================] - 54s 137ms/step - loss: 0.0711 - acc: 0.9757 - val_loss: 0.5907 - val_acc: 0.8610
# Epoch 35/100
#
# Epoch 00035: LearningRateScheduler setting learning rate to 0.00025325.
# 391/390 [==============================] - 56s 144ms/step - loss: 0.0661 - acc: 0.9762 - val_loss: 0.6031 - val_acc: 0.8620
# Epoch 36/100
#
# Epoch 00036: LearningRateScheduler setting learning rate to 0.0002466091.
# 391/390 [==============================] - 55s 140ms/step - loss: 0.0678 - acc: 0.9766 - val_loss: 0.6117 - val_acc: 0.8546
# Epoch 37/100
#
# Epoch 00037: LearningRateScheduler setting learning rate to 0.0002403076.
# 391/390 [==============================] - 54s 137ms/step - loss: 0.0668 - acc: 0.9761 - val_loss: 0.5862 - val_acc: 0.8641
# Epoch 38/100
#
# Epoch 00038: LearningRateScheduler setting learning rate to 0.0002343201.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0608 - acc: 0.9791 - val_loss: 0.6071 - val_acc: 0.8598
# Epoch 39/100
#
# Epoch 00039: LearningRateScheduler setting learning rate to 0.0002286237.
# 391/390 [==============================] - 54s 137ms/step - loss: 0.0609 - acc: 0.9781 - val_loss: 0.5846 - val_acc: 0.8654
# Epoch 40/100
#
# Epoch 00040: LearningRateScheduler setting learning rate to 0.0002231977.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0549 - acc: 0.9809 - val_loss: 0.6122 - val_acc: 0.8649
# Epoch 41/100
#
# Epoch 00041: LearningRateScheduler setting learning rate to 0.0002180233.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0554 - acc: 0.9809 - val_loss: 0.6080 - val_acc: 0.8650
# Epoch 42/100
#
# Epoch 00042: LearningRateScheduler setting learning rate to 0.0002130833.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0552 - acc: 0.9802 - val_loss: 0.6206 - val_acc: 0.8606
# Epoch 43/100
#
# Epoch 00043: LearningRateScheduler setting learning rate to 0.0002083623.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0525 - acc: 0.9815 - val_loss: 0.6347 - val_acc: 0.8618
# Epoch 44/100
#
# Epoch 00044: LearningRateScheduler setting learning rate to 0.0002038459.
# 391/390 [==============================] - 54s 137ms/step - loss: 0.0512 - acc: 0.9814 - val_loss: 0.6098 - val_acc: 0.8648
# Epoch 45/100
#
# Epoch 00045: LearningRateScheduler setting learning rate to 0.0001995211.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0500 - acc: 0.9819 - val_loss: 0.6399 - val_acc: 0.8598
# Epoch 46/100
#
# Epoch 00046: LearningRateScheduler setting learning rate to 0.0001953761.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0487 - acc: 0.9827 - val_loss: 0.6422 - val_acc: 0.8629
# Epoch 47/100
#
# Epoch 00047: LearningRateScheduler setting learning rate to 0.0001913998.
# 391/390 [==============================] - 63s 162ms/step - loss: 0.0487 - acc: 0.9831 - val_loss: 0.6224 - val_acc: 0.8642
# Epoch 48/100
#
# Epoch 00048: LearningRateScheduler setting learning rate to 0.0001875821.
# 391/390 [==============================] - 105s 268ms/step - loss: 0.0474 - acc: 0.9836 - val_loss: 0.6265 - val_acc: 0.8662
# Epoch 49/100
#
# Epoch 00049: LearningRateScheduler setting learning rate to 0.0001839137.
# 391/390 [==============================] - 105s 269ms/step - loss: 0.0449 - acc: 0.9840 - val_loss: 0.6184 - val_acc: 0.8671
# Epoch 50/100
#
# Epoch 00050: LearningRateScheduler setting learning rate to 0.000180386.
# 391/390 [==============================] - 57s 147ms/step - loss: 0.0469 - acc: 0.9836 - val_loss: 0.6365 - val_acc: 0.8664
# Epoch 51/100
#
# Epoch 00051: LearningRateScheduler setting learning rate to 0.0001769912.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0438 - acc: 0.9852 - val_loss: 0.6170 - val_acc: 0.8690
# Epoch 52/100
#
# Epoch 00052: LearningRateScheduler setting learning rate to 0.0001737217.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0441 - acc: 0.9844 - val_loss: 0.6372 - val_acc: 0.8657
# Epoch 53/100
#
# Epoch 00053: LearningRateScheduler setting learning rate to 0.0001705708.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0443 - acc: 0.9843 - val_loss: 0.6298 - val_acc: 0.8670
# Epoch 54/100
#
# Epoch 00054: LearningRateScheduler setting learning rate to 0.0001675322.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0405 - acc: 0.9859 - val_loss: 0.6503 - val_acc: 0.8626
# Epoch 55/100
#
# Epoch 00055: LearningRateScheduler setting learning rate to 0.0001646.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0413 - acc: 0.9857 - val_loss: 0.6347 - val_acc: 0.8646
# Epoch 56/100
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001617687.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0404 - acc: 0.9863 - val_loss: 0.6246 - val_acc: 0.8630
# Epoch 57/100
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001590331.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0386 - acc: 0.9868 - val_loss: 0.6262 - val_acc: 0.8653
# Epoch 58/100
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001563885.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0387 - acc: 0.9870 - val_loss: 0.6358 - val_acc: 0.8641
# Epoch 59/100
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001538304.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0359 - acc: 0.9873 - val_loss: 0.6475 - val_acc: 0.8654
# Epoch 60/100
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001513546.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0364 - acc: 0.9876 - val_loss: 0.6435 - val_acc: 0.8681
# Epoch 61/100
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001489573.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0365 - acc: 0.9879 - val_loss: 0.6368 - val_acc: 0.8692
# Epoch 62/100
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001466347.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0338 - acc: 0.9882 - val_loss: 0.6625 - val_acc: 0.8651
# Epoch 63/100
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001443835.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0362 - acc: 0.9878 - val_loss: 0.6733 - val_acc: 0.8654
# Epoch 64/100
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001422003.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0353 - acc: 0.9872 - val_loss: 0.6650 - val_acc: 0.8675
# Epoch 65/100
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001400822.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0350 - acc: 0.9877 - val_loss: 0.6321 - val_acc: 0.8704
# Epoch 66/100
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001380262.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0339 - acc: 0.9882 - val_loss: 0.6615 - val_acc: 0.8653
# Epoch 67/100
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001360297.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0332 - acc: 0.9885 - val_loss: 0.6358 - val_acc: 0.8705
# Epoch 68/100
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001340902.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0322 - acc: 0.9885 - val_loss: 0.6490 - val_acc: 0.8710
# Epoch 69/100
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001322052.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0331 - acc: 0.9889 - val_loss: 0.6449 - val_acc: 0.8666
# Epoch 70/100
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001303724.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0307 - acc: 0.9894 - val_loss: 0.6771 - val_acc: 0.8648
# Epoch 71/100
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.0001285898.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0319 - acc: 0.9892 - val_loss: 0.6598 - val_acc: 0.8650
# Epoch 72/100
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.0001268553.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0321 - acc: 0.9885 - val_loss: 0.6341 - val_acc: 0.8715
# Epoch 73/100
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.0001251669.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0303 - acc: 0.9898 - val_loss: 0.6438 - val_acc: 0.8719
# Epoch 74/100
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.0001235229.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0321 - acc: 0.9889 - val_loss: 0.6515 - val_acc: 0.8729
# Epoch 75/100
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.0001219215.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0299 - acc: 0.9891 - val_loss: 0.6364 - val_acc: 0.8712
# Epoch 76/100
#
# Epoch 00076: LearningRateScheduler setting learning rate to 0.0001203611.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0265 - acc: 0.9905 - val_loss: 0.6472 - val_acc: 0.8722
# Epoch 77/100
#
# Epoch 00077: LearningRateScheduler setting learning rate to 0.0001188401.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0290 - acc: 0.9895 - val_loss: 0.6442 - val_acc: 0.8732
# Epoch 78/100
#
# Epoch 00078: LearningRateScheduler setting learning rate to 0.0001173571.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0280 - acc: 0.9900 - val_loss: 0.6434 - val_acc: 0.8726
# Epoch 79/100
#
# Epoch 00079: LearningRateScheduler setting learning rate to 0.0001159107.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0275 - acc: 0.9903 - val_loss: 0.6419 - val_acc: 0.8752
# Epoch 80/100
#
# Epoch 00080: LearningRateScheduler setting learning rate to 0.0001144994.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0282 - acc: 0.9905 - val_loss: 0.6491 - val_acc: 0.8716
# Epoch 81/100
#
# Epoch 00081: LearningRateScheduler setting learning rate to 0.0001131222.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0279 - acc: 0.9904 - val_loss: 0.6752 - val_acc: 0.8670
# Epoch 82/100
#
# Epoch 00082: LearningRateScheduler setting learning rate to 0.0001117776.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0246 - acc: 0.9915 - val_loss: 0.6556 - val_acc: 0.8727
# Epoch 83/100
#
# Epoch 00083: LearningRateScheduler setting learning rate to 0.0001104647.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0270 - acc: 0.9909 - val_loss: 0.6725 - val_acc: 0.8705
# Epoch 84/100
#
# Epoch 00084: LearningRateScheduler setting learning rate to 0.0001091822.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0271 - acc: 0.9908 - val_loss: 0.6587 - val_acc: 0.8737
# Epoch 85/100
#
# Epoch 00085: LearningRateScheduler setting learning rate to 0.0001079292.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0263 - acc: 0.9909 - val_loss: 0.6613 - val_acc: 0.8726
# Epoch 86/100
#
# Epoch 00086: LearningRateScheduler setting learning rate to 0.0001067046.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0236 - acc: 0.9915 - val_loss: 0.6576 - val_acc: 0.8726
# Epoch 87/100
#
# Epoch 00087: LearningRateScheduler setting learning rate to 0.0001055075.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0249 - acc: 0.9914 - val_loss: 0.6651 - val_acc: 0.8714
# Epoch 88/100
#
# Epoch 00088: LearningRateScheduler setting learning rate to 0.0001043369.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0231 - acc: 0.9920 - val_loss: 0.6694 - val_acc: 0.8727
# Epoch 89/100
#
# Epoch 00089: LearningRateScheduler setting learning rate to 0.0001031921.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0238 - acc: 0.9920 - val_loss: 0.6602 - val_acc: 0.8707
# Epoch 90/100
#
# Epoch 00090: LearningRateScheduler setting learning rate to 0.0001020721.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0257 - acc: 0.9909 - val_loss: 0.6604 - val_acc: 0.8721
# Epoch 91/100
#
# Epoch 00091: LearningRateScheduler setting learning rate to 0.0001009761.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0260 - acc: 0.9906 - val_loss: 0.6589 - val_acc: 0.8748
# Epoch 92/100
#
# Epoch 00092: LearningRateScheduler setting learning rate to 9.99034e-05.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0240 - acc: 0.9919 - val_loss: 0.6639 - val_acc: 0.8733
# Epoch 93/100
#
# Epoch 00093: LearningRateScheduler setting learning rate to 9.88533e-05.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0228 - acc: 0.9920 - val_loss: 0.6838 - val_acc: 0.8711
# Epoch 94/100
#
# Epoch 00094: LearningRateScheduler setting learning rate to 9.7825e-05.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0249 - acc: 0.9915 - val_loss: 0.6786 - val_acc: 0.8701
# Epoch 95/100
#
# Epoch 00095: LearningRateScheduler setting learning rate to 9.68179e-05.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0226 - acc: 0.9925 - val_loss: 0.6708 - val_acc: 0.8708
# Epoch 96/100
#
# Epoch 00096: LearningRateScheduler setting learning rate to 9.58313e-05.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0234 - acc: 0.9923 - val_loss: 0.6826 - val_acc: 0.8687
# Epoch 97/100
#
# Epoch 00097: LearningRateScheduler setting learning rate to 9.48647e-05.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0234 - acc: 0.9921 - val_loss: 0.6704 - val_acc: 0.8701
# Epoch 98/100
#
# Epoch 00098: LearningRateScheduler setting learning rate to 9.39173e-05.
# 391/390 [==============================] - 54s 139ms/step - loss: 0.0228 - acc: 0.9924 - val_loss: 0.6726 - val_acc: 0.8717
# Epoch 99/100
#
# Epoch 00099: LearningRateScheduler setting learning rate to 9.29887e-05.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0216 - acc: 0.9925 - val_loss: 0.6737 - val_acc: 0.8725
# Epoch 100/100
#
# Epoch 00100: LearningRateScheduler setting learning rate to 9.20782e-05.
# 391/390 [==============================] - 54s 138ms/step - loss: 0.0222 - acc: 0.9927 - val_loss: 0.6726 - val_acc: 0.8739
# Model took 6334.66 seconds to train
# Accuracy on test data is: 87.39

# %% [markdown]
# ## Accuracy on test data is: 87.39

# %%
y_pred = model.predict_generator(datagen.flow(test_features, test_labels,shuffle=False, batch_size = 128),steps=len(test_features)/128)

y_pred_argmax = np.argmax(np.rint(y_pred), axis=1)

y_argmax = np.argmax(np.rint(test_labels), axis=1)
index= []

for x in range(y_pred_argmax.shape[0]):
  if y_pred_argmax[x] != y_argmax[x]:
    index.append(x)
    
print(len(index))
# Out:
# 1275

# %% [markdown]
# ## GradCAM

# %%
def getHeatMapFromLayer(layer_name,image):
  x = np.expand_dims(image, axis=0)
  preds = model.predict(x)
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer(layer_name)
  
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([x])
  for i in range(10):
      conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
  
  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)
  return heatmap

# %% [markdown]
# ## GradCAM on selected four Images

# %%
# Selecting 4 images from dataset
idx = [39,210,304,437]
fig, ax = plt.subplots(2, 4, figsize = (20,6))

for i, val in enumerate(idx): 
  print (i, ": Image class Id",val)
  img = test_features[val]*255
  heatmap = getHeatMapFromLayer('conv2d_24',img)
  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_HSV)
  superimposed_img = cv2.addWeighted(img.astype(float), 0.6, heatmap.astype(float), 0.4, 0)
  ax[0, i].imshow(img/255)
  ax[1, i].imshow(superimposed_img/255)
  
plt.show()
# Out:
# 0 : Image class Id 39
# 1 : Image class Id 210
# 2 : Image class Id 304
# 3 : Image class Id 437
