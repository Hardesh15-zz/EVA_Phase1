# %% [markdown]
# ## Importing Keras Libraries and Modules

# %%
from keras import backend as K
import numpy as np
import time
import cv2
import sys
# Importing matplot library
import matplotlib.pyplot as plt
% matplotlib inline
# Seed the generator
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D,Conv2D
from keras.layers import Activation, Flatten, Dense, Dropout,SpatialDropout2D
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils

# %% [markdown]
# ##Importing Cifar10 dataset

# %%
# Importing Cifar10 dataset
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %%
# Ploting each class from cifar10 dataset
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
# Function to plot model history
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
# Function to define accuracy
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
# Function for CutOut
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

# %%
# Define the model
model = Sequential()

model.add(Conv2D(48, (3, 3), activation='relu', padding ='same', input_shape=(32, 32, 3))) #32
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Conv2D(48, (3, 3), activation='relu')) #30
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(MaxPooling2D(pool_size=(2, 2))) #15


model.add(Conv2D(96, (3, 3), activation='relu', padding ='same')) # 15
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Conv2D(96, (3, 3), activation='relu')) # 13
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Conv2D(96, (3, 3), activation='relu')) # 11
model.add(BatchNormalization())
model.add(Dropout(0.25))


model.add(MaxPooling2D(pool_size=(2, 2))) #5


model.add(Conv2D(192, (3, 3), activation='relu', padding ='same')) #5
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Conv2D(192, (3, 3), activation='relu')) # 5
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Conv2D(192, (3, 3), activation='relu')) # 3
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(10, 1, name = 'last_layer')) #1

model.add(Flatten())
model.add(Activation('softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Summary of model
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_9 (Conv2D)            (None, 32, 32, 48)        1344
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 32, 32, 48)        192
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 32, 32, 48)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 30, 30, 48)        20784
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 30, 30, 48)        192
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 30, 30, 48)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 48)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 15, 15, 96)        41568
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 15, 15, 96)        384
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 15, 15, 96)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 13, 13, 96)        83040
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 13, 13, 96)        384
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 13, 13, 96)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 11, 11, 96)        83040
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 11, 11, 96)        384
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 11, 11, 96)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 5, 96)          0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 5, 5, 192)         166080
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 5, 5, 192)         768
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 5, 5, 192)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 3, 3, 192)         331968
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 3, 3, 192)         768
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 3, 3, 192)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 1, 1, 192)         331968
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 1, 1, 192)         768
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 1, 1, 192)         0
# _________________________________________________________________
# last_layer (Conv2D)          (None, 1, 1, 10)          1930
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# =================================================================
# Total params: 1,065,562
# Trainable params: 1,063,642
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
# Image Normalization
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint,LearningRateScheduler
#datagen = ImageDataGenerator(zoom_range=0.0,horizontal_flip=False)
datagen = ImageDataGenerator(preprocessing_function=get_random_eraser(v_l=0, v_h=1))
# train the model
start = time.time()
def scheduler(epoch, lr):
  return round(0.003 * 1/(1 + 0.319 * epoch), 10)

from google.colab import drive
drive.mount('/content/drive')
checkpoint = ModelCheckpoint('/content/drive/My Drive/BestModel_7B_3.hdf5',monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto')

# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 steps_per_epoch = train_features.shape[0]/128, epochs = 75, 
                                 validation_data = (test_features, test_labels),callbacks=[checkpoint,LearningRateScheduler(scheduler, verbose=1)])
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))

# plot model history
plot_model_history(model_info)

# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Epoch 1/75
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.003.
# 391/390 [==============================] - 101s 259ms/step - loss: 1.6928 - acc: 0.4002 - val_loss: 1.5185 - val_acc: 0.4434
# Epoch 2/75
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.0022744503.
# 391/390 [==============================] - 98s 251ms/step - loss: 1.1896 - acc: 0.5718 - val_loss: 1.3367 - val_acc: 0.5588
# Epoch 3/75
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.0018315018.
# 391/390 [==============================] - 98s 251ms/step - loss: 0.9776 - acc: 0.6524 - val_loss: 1.1084 - val_acc: 0.6381
# Epoch 4/75
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.0015329586.
#

# 391/390 [==============================] - 75s 192ms/step - loss: 0.2366 - acc: 0.9174 - val_loss: 0.4895 - val_acc: 0.8497
# Epoch 56/75
#
# Epoch 00056: LearningRateScheduler setting learning rate to 0.0001617687.
# 391/390 [==============================] - 75s 193ms/step - loss: 0.2371 - acc: 0.9160 - val_loss: 0.4917 - val_acc: 0.8530
# Epoch 57/75
#
# Epoch 00057: LearningRateScheduler setting learning rate to 0.0001590331.
# 391/390 [==============================] - 75s 192ms/step - loss: 0.2341 - acc: 0.9185 - val_loss: 0.4831 - val_acc: 0.8568
# Epoch 58/75
#
# Epoch 00058: LearningRateScheduler setting learning rate to 0.0001563885.
# 391/390 [==============================] - 75s 192ms/step - loss: 0.2275 - acc: 0.9202 - val_loss: 0.4951 - val_acc: 0.8525
# Epoch 59/75
#
# Epoch 00059: LearningRateScheduler setting learning rate to 0.0001538304.
# 391/390 [==============================] - 75s 192ms/step - loss: 0.2301 - acc: 0.9192 - val_loss: 0.4916 - val_acc: 0.8537
# Epoch 60/75
#
# Epoch 00060: LearningRateScheduler setting learning rate to 0.0001513546.
# 391/390 [==============================] - 75s 192ms/step - loss: 0.2282 - acc: 0.9192 - val_loss: 0.4803 - val_acc: 0.8558
# Epoch 61/75
#
# Epoch 00061: LearningRateScheduler setting learning rate to 0.0001489573.
# 391/390 [==============================] - 75s 192ms/step - loss: 0.2257 - acc: 0.9211 - val_loss: 0.4799 - val_acc: 0.8581
# Epoch 62/75
#
# Epoch 00062: LearningRateScheduler setting learning rate to 0.0001466347.
# 391/390 [==============================] - 75s 191ms/step - loss: 0.2240 - acc: 0.9198 - val_loss: 0.4947 - val_acc: 0.8549
# Epoch 63/75
#
# Epoch 00063: LearningRateScheduler setting learning rate to 0.0001443835.
# 391/390 [==============================] - 75s 191ms/step - loss: 0.2215 - acc: 0.9219 - val_loss: 0.4826 - val_acc: 0.8566
# Epoch 64/75
#
# Epoch 00064: LearningRateScheduler setting learning rate to 0.0001422003.
# 391/390 [==============================] - 75s 192ms/step - loss: 0.2207 - acc: 0.9232 - val_loss: 0.4936 - val_acc: 0.8551
# Epoch 65/75
#
# Epoch 00065: LearningRateScheduler setting learning rate to 0.0001400822.
# 391/390 [==============================] - 75s 192ms/step - loss: 0.2225 - acc: 0.9220 - val_loss: 0.4930 - val_acc: 0.8542
# Epoch 66/75
#
# Epoch 00066: LearningRateScheduler setting learning rate to 0.0001380262.
# 391/390 [==============================] - 75s 191ms/step - loss: 0.2191 - acc: 0.9233 - val_loss: 0.4725 - val_acc: 0.8613
# Epoch 67/75
#
# Epoch 00067: LearningRateScheduler setting learning rate to 0.0001360297.
# 391/390 [==============================] - 75s 191ms/step - loss: 0.2186 - acc: 0.9229 - val_loss: 0.4853 - val_acc: 0.8600
# Epoch 68/75
#
# Epoch 00068: LearningRateScheduler setting learning rate to 0.0001340902.
# 391/390 [==============================] - 75s 192ms/step - loss: 0.2161 - acc: 0.9241 - val_loss: 0.5013 - val_acc: 0.8541
# Epoch 69/75
#
# Epoch 00069: LearningRateScheduler setting learning rate to 0.0001322052.
# 391/390 [==============================] - 75s 192ms/step - loss: 0.2195 - acc: 0.9244 - val_loss: 0.4874 - val_acc: 0.8570
# Epoch 70/75
#
# Epoch 00070: LearningRateScheduler setting learning rate to 0.0001303724.
# 391/390 [==============================] - 75s 191ms/step - loss: 0.2128 - acc: 0.9254 - val_loss: 0.4910 - val_acc: 0.8535
# Epoch 71/75
#
# Epoch 00071: LearningRateScheduler setting learning rate to 0.0001285898.
# 391/390 [==============================] - 75s 191ms/step - loss: 0.2168 - acc: 0.9240 - val_loss: 0.4834 - val_acc: 0.8582
# Epoch 72/75
#
# Epoch 00072: LearningRateScheduler setting learning rate to 0.0001268553.
# 391/390 [==============================] - 74s 190ms/step - loss: 0.2097 - acc: 0.9269 - val_loss: 0.4695 - val_acc: 0.8635
# Epoch 73/75
#
# Epoch 00073: LearningRateScheduler setting learning rate to 0.0001251669.
# 391/390 [==============================] - 75s 191ms/step - loss: 0.2098 - acc: 0.9267 - val_loss: 0.4810 - val_acc: 0.8589
# Epoch 74/75
#
# Epoch 00074: LearningRateScheduler setting learning rate to 0.0001235229.
# 391/390 [==============================] - 75s 191ms/step - loss: 0.2116 - acc: 0.9250 - val_loss: 0.4777 - val_acc: 0.8605
# Epoch 75/75
#
# Epoch 00075: LearningRateScheduler setting learning rate to 0.0001219215.
# 391/390 [==============================] - 75s 192ms/step - loss: 0.2064 - acc: 0.9283 - val_loss: 0.4813 - val_acc: 0.8599
# Model took 5649.04 seconds to train
# Accuracy on test data is: 85.99

# %% [markdown]
# ## Grad-CAM

# %%
idx = [19,210,504,435]
selected_images = [test_features[i] for i, _ in enumerate(test_features) if i in idx]
for img_path in selected_images:
  print("Initial Image Shape", img_path.shape)
  x = np.expand_dims(img_path,axis = 0)
  preds = model.predict(x)
  class_idx = np.argmax(preds[0])
  class_output = model.output[:, class_idx]
  last_conv_layer = model.get_layer("last_layer")
   
  grads = K.gradients(class_output, last_conv_layer.output)[0]
  pooled_grads = K.mean(grads, axis=(0, 1, 2))
  iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
  pooled_grads_value, conv_layer_output_value = iterate([x])
  
  for i in range(4):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
  heatmap = np.mean(conv_layer_output_value, axis=-1)
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)
  img = img_path
  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
  heatmap = np.uint8(255 * heatmap)
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_HSV)
  superimposed_img = cv2.addWeighted(img, 0.8, heatmap, 0.2, 0,dtype = cv2.CV_32F)
  plt.imshow(img)
  plt.show() 
  plt.imshow(superimposed_img)
  plt.show()
# Out:
# Initial Image Shape (32, 32, 3)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in true_divide
# W0629 16:24:07.655903 140295441004416 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Initial Image Shape (32, 32, 3)
# W0629 16:24:08.977865 140295441004416 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Initial Image Shape (32, 32, 3)
# W0629 16:24:10.249882 140295441004416 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Initial Image Shape (32, 32, 3)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: RuntimeWarning: invalid value encountered in true_divide
# W0629 16:24:11.556722 140295441004416 image.py:648] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
